# %%
import math
import matplotlib.pyplot as plt
# %run Punto.ipynb
# %run Circunferencia.ipynb
# %run Cluster.ipynb
# %run leer_datos.ipynb
# %run grado_pertenencia.ipynb
# %run grafico.ipynb
# %run k_medias.ipynb
# %matplotlib inline

# %% [markdown]
# ## EJEMPLO 1

# %%
k = 2
datos = leer_datos('ejemplo_1.csv',k)
puntos = datos[0]
circunferencias = datos[1]

# %%
umbral = 0.95
cls = k_medias(puntos,circunferencias,200,umbral)
generar_grafico(puntos,cls)

# %% [markdown]
# ## EJEMPLO 2

# %%
k = 3
datos = leer_datos('ejemplo_2.csv',k)
puntos = datos[0]
circunferencias = datos[1]

# %%
umbral = 0.95
cls = k_medias(puntos,circunferencias,200,umbral)
generar_grafico(puntos,cls)

# %% [markdown]
# ## EJEMPLO 3

# %%
k = 2
datos = leer_datos('ejemplo_3.csv',k)
puntos = datos[0]
circunferencias = datos[1]

# %%
umbral = 0.95
cls = k_medias(puntos,circunferencias,200,umbral)
generar_grafico(puntos,cls)

# %% [markdown]
# ## EJEMPLO 4

# %%
k = 3
datos = leer_datos('ejemplo_4.csv',k)
puntos = datos[0]
circunferencias = datos[1]

# %%
umbral = 0.95
cls = k_medias(puntos,circunferencias,200,umbral)
generar_grafico(puntos,cls)

# %% [markdown]
# ## EJEMPLO 5

# %%
k = 5
datos = leer_datos('ejemplo_5.csv',k)
puntos = datos[0]
circunferencias = datos[1]

# %%
umbral = 0.95
cls = k_medias(puntos,circunferencias,200,umbral)
generar_grafico(puntos,cls)
